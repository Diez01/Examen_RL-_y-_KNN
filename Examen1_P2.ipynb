# %% [markdown]
# 1er Examen
#
# Parte 2. Usando el dataset de breast_cancer_data.csv realiza lo siguiente:

# %%
import ia_misc as ia
import numpy as np
import pandas as pd
import plotly.express as px

dataset = pd.read_csv('./Datasets/breast_cancer_data.csv')
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# a. Usa las diferentes columnas del dataset para observar si tienen una buena correlación entre los datos, también puedes usar el coeficiente de Pearson para saber que tanta correlación tienen los datos.

# %%
columna = 'perimeter_mean'

fig = px.scatter(
    dataset,
    x=columna,
    y=np.zeros(len(dataset[columna])),
    color='diagnosis',
    width=500
)

fig.update_traces(marker=dict(size=2))
# Out:
# c:\Users\segan\anaconda3\envs\IA2024\lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
fig = px.scatter(
    dataset,
    x='radius_mean',
    y='texture_mean',
    color='diagnosis',
    width=500
)

fig.update_traces(marker=dict(size=2))
# Out:
# c:\Users\segan\anaconda3\envs\IA2024\lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
fig = px.scatter_3d(
    dataset,
    x='radius_mean',
    y='texture_mean',
    z='smoothness_mean',
    color='diagnosis',
    width=500
)

fig.update_traces(marker=dict(size=2))
# Out:
# c:\Users\segan\anaconda3\envs\IA2024\lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %% [markdown]
# b. Usando una de las 3 funciones para separar los datos para KNN (están separadas por dimensiones), obten tus dos matrices de entrenamiento y clasificación.

# %%
# Ejemplo de separación de los datos con 2 dimensiones

x = dataset['radius_mean'].to_numpy()
y = dataset['texture_mean'].to_numpy()
c = np.zeros(len(x))
c[dataset[dataset['diagnosis']=='B'].index.to_numpy()] = 0
c[dataset[dataset['diagnosis']=='M'].index.to_numpy()] = 1

train_data, pred_data = ia.trainPredSeparationKNN2D(x,y,c)

# %%
# Escribir código aquí

# %% [markdown]
# c. Con el objeto creado en ia_misc (KNN), entrena y calcula la precisión de tu entrenamiento con un valor por default de k de 1.

# %%
# Escribir código aquí

# %% [markdown]
# d. Usando diferentes valores de k, calcula su valor óptimo.

# %%
# Escribir código aquí

# %% [markdown]
# e. Realiza la clasificación con el valor óptimo de k.

# %%
# Escribir código aquí

# %% [markdown]
# f. Redacta tus conclusiones en un bloque de Markdown. (Respuesta libre)
#
# Respuesta:
